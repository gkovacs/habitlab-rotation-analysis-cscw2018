# %%
import json

# %%
datafile = 'data_march28_2am.json'
alldata = json.load(open(datafile))

# %%
from extract_dataframe import extract_dataframe, is_youtube, is_default_youtube_intervention

# %%
data = extract_dataframe(alldata, [is_youtube, is_default_youtube_intervention])

# %%
from scipy.stats import f_oneway

# %%
f_oneway(data[])
# Out:
#     condition           domain                install_id  \
# 0        same  www.youtube.com  07bb2f65ed57bcc90dfea618
# 1        same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 2        same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 3        same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 4        same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 5        same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 6        same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 7        same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 8        same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 9        same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 10       same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 11       same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 12       same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 13       same  www.youtube.com  3ec25c714a854b5f574e1f5e
# 14       same  www.youtube.com  3ec25c714a854b5f574e1f5e
# ...
